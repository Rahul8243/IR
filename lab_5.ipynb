# %%
import requests
from bs4 import BeautifulSoup
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
def extract_text_from_url(url):
    response = requests.get(url, timeout=10)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, "html.parser")

    # Remove unwanted tags
    for tag in soup(["script", "style", "noscript"]):
        tag.decompose()

    text = soup.get_text(separator=" ")
    clean_text = " ".join(text.split())

    return clean_text

# %%
url = "https://www.geeksforgeeks.org/nlp/natural-language-processing-nlp-tutorial"

text = extract_text_from_url(url)
print("\n--- Extracted Text ---\n")
print(text[:500])
# Out:
# --- Extracted Text ---
#
# Natural Language Processing (NLP) Tutorial - GeeksforGeeks Courses Tutorials Interview Prep NLP Tutorial Libraries Phases Text Preprosessing Tokenization Lemmatization Word Embeddings Projects Ideas Interview Question NLP Quiz NLP Pipeline DL for NLP Natural Language Processing (NLP) Tutorial Last Updated : 24 Feb, 2026 Natural Language Processing (NLP) helps machines to understand and process human languages either in text or audio form. It is used across a variety of applications from speech r

# %%
def tokenize_text(text):
    return word_tokenize(text.lower())

tokens = tokenize_text(text)
print("\n--- Tokens ---\n")
print(tokens[:50])
# Out:
# --- Tokens ---
#
# ['natural', 'language', 'processing', '(', 'nlp', ')', 'tutorial', '-', 'geeksforgeeks', 'courses', 'tutorials', 'interview', 'prep', 'nlp', 'tutorial', 'libraries', 'phases', 'text', 'preprosessing', 'tokenization', 'lemmatization', 'word', 'embeddings', 'projects', 'ideas', 'interview', 'question', 'nlp', 'quiz', 'nlp', 'pipeline', 'dl', 'for', 'nlp', 'natural', 'language', 'processing', '(', 'nlp', ')', 'tutorial', 'last', 'updated', ':', '24', 'feb', ',', '2026', 'natural', 'language']

# %%
def remove_stopwords(tokens):
    stop_words = set(stopwords.words("english"))
    return [word for word in tokens if word not in stop_words]

tokens = remove_stopwords(tokens)
print("\n--- After Stopword Removal ---\n")
print(tokens[:50])
# Out:
# --- After Stopword Removal ---
#
# ['natural', 'language', 'processing', '(', 'nlp', ')', 'tutorial', '-', 'geeksforgeeks', 'courses', 'tutorials', 'interview', 'prep', 'nlp', 'tutorial', 'libraries', 'phases', 'text', 'preprosessing', 'tokenization', 'lemmatization', 'word', 'embeddings', 'projects', 'ideas', 'interview', 'question', 'nlp', 'quiz', 'nlp', 'pipeline', 'dl', 'nlp', 'natural', 'language', 'processing', '(', 'nlp', ')', 'tutorial', 'last', 'updated', ':', '24', 'feb', ',', '2026', 'natural', 'language', 'processing']

# %%
def stem_tokens(tokens):
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]

tokens = stem_tokens(tokens)
print("\n--- After Stemming ---\n")
print(tokens[:50])
# Out:
# --- After Stemming ---
#
# ['natur', 'languag', 'process', '(', 'nlp', ')', 'tutori', '-', 'geeksforgeek', 'cours', 'tutori', 'interview', 'prep', 'nlp', 'tutori', 'librari', 'phase', 'text', 'preprosess', 'token', 'lemmat', 'word', 'embed', 'project', 'idea', 'interview', 'question', 'nlp', 'quiz', 'nlp', 'pipelin', 'dl', 'nlp', 'natur', 'languag', 'process', '(', 'nlp', ')', 'tutori', 'last', 'updat', ':', '24', 'feb', ',', '2026', 'natur', 'languag', 'process']
